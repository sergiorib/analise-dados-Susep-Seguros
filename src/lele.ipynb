# %%
import pandas as pd

# %% [markdown]
# Esse codigo foi o lele que fez, se der erro não tenho culpa

# %%
df = pd.read_csv('Ses_seguros.csv', sep=';')

# %%
df.describe()
# Out:
#            coenti       cogrupo       coramo  premio_emitido2  \
# count   100.00000    100.000000   100.000000            100.0
# mean   5164.97000  61176.190000   299.700000              0.0
# std    1194.70257  48798.371018   355.165447              0.0
# min   -5096.00000     19.000000    11.000000              0.0
# 25%    5096.00000    571.750000    54.750000              0.0
# 50%    5096.00000  99999.000000    82.500000              0.0
# 75%    5631.00000  99999.000000   588.250000              0.0
# max    5762.00000  99999.000000  1164.000000              0.0
#
#        premio_emitido_cap  despesa_resseguros  sinistro_ocorrido  \
# count               100.0               100.0              100.0
# mean                  0.0                 0.0                0.0
# std                   0.0                 0.0                0.0
# min                   0.0                 0.0                0.0
# 25%                   0.0                 0.0                0.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 21 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   damesano                             100 non-null    object
#  1   coenti                               100 non-null    int64
#  2   cogrupo                              100 non-null    int64
#  3   coramo                               100 non-null    int64
#  4   premio_direto                        100 non-null    object
#  5   premio_de_seguros                    100 non-null    object
#  6   premio_retido                        100 non-null    object
#  7   premio_ganho                         100 non-null    object
#  8   sinistro_direto                      100 non-null    object
#  9   sinistro_retido                      100 non-null    object
#  10  desp_com                             100 non-null    object
# ...
